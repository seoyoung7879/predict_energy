# %%
import pandas as pd
import os

# %%
import os
import pandas as pd

# ✅ 현재 폴더 기준
folder_path = "."  # 또는 os.getcwd()

# ✅ 현재 폴더 내 모든 CSV 파일 가져오기
file_list = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# ✅ 파일별로 읽어서 리스트에 저장
df_list = [pd.read_csv(os.path.join(folder_path, file), encoding='cp949') for file in file_list]

# ✅ 데이터프레임 병합
merged_df = pd.concat(df_list, ignore_index=True)

# ✅ 결과 저장
merged_df.to_csv('부산_병합2.csv', index=False, encoding='utf-8-sig')

print(f"📁 병합 완료: {len(file_list)}개 파일 → merged_result.csv 저장됨")
# Out:
# 📁 병합 완료: 13개 파일 → merged_result.csv 저장됨

# %%
df = pd.read_csv("merged_result.csv", encoding = "utf-8")

# %%
df.head()
# Out:
#     지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0  159  부산  2013-01-01 00:00    -2.3      NaN      1.6     340.0   51.0
# 1  159  부산  2013-01-01 01:00    -2.4      NaN      1.8     340.0   54.0
# 2  159  부산  2013-01-01 02:00    -2.5      NaN      1.9     340.0   53.0
# 3  159  부산  2013-01-01 03:00    -2.0      NaN      1.7     320.0   52.0
# 4  159  부산  2013-01-01 04:00    -2.3      NaN      2.1     320.0   54.0
#
#    현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)
# 0     1012.5     NaN        NaN     NaN        0.0
# 1     1012.3     NaN        NaN     NaN        NaN
# 2     1013.3     NaN        NaN     NaN        NaN
# 3     1013.4     NaN        NaN     NaN        6.0
# 4     1013.0     NaN        NaN     NaN        0.0

# %%
df = df.drop(columns = ["지점"])

# %%
df.head()
# Out:
#   지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  현지기압(hPa)  \
# 0  부산  2013-01-01 00:00    -2.3      NaN      1.6     340.0   51.0     1012.5
# 1  부산  2013-01-01 01:00    -2.4      NaN      1.8     340.0   54.0     1012.3
# 2  부산  2013-01-01 02:00    -2.5      NaN      1.9     340.0   53.0     1013.3
# 3  부산  2013-01-01 03:00    -2.0      NaN      1.7     320.0   52.0     1013.4
# 4  부산  2013-01-01 04:00    -2.3      NaN      2.1     320.0   54.0     1013.0
#
#    일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)
# 0     NaN        NaN     NaN        0.0
# 1     NaN        NaN     NaN        NaN
# 2     NaN        NaN     NaN        NaN
# 3     NaN        NaN     NaN        6.0
# 4     NaN        NaN     NaN        0.0

# %%
df.to_csv("부산 병합.csv", encoding = "utf-8")
