# %%
import pandas as pd
import os

# %%
# ✅ CSV 파일들이 있는 폴더 경로
folder_path =  "C:\\Users\\kelly\\Desktop\\GitHub\\predict_energy\\태양광\\1. 데이터 전처리 및 EDA\\추가 발전소\\신풍리(21.05-25.02)" # 예: 'data/' 또는 './csv_files/'

# ✅ 해당 폴더 내 모든 CSV 파일 이름 가져오기
file_list = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# ✅ 각 CSV 파일을 읽어서 리스트에 저장
df_list = [pd.read_csv(os.path.join(folder_path, file), encoding='cp949') for file in file_list]

# ✅ 데이터프레임들을 하나로 병합
merged_df = pd.concat(df_list, ignore_index=True)

# ✅ 병합된 결과를 새로운 CSV로 저장 (선택)
merged_df.to_csv('merged_result.csv', index=False, encoding='utf-8-sig')

# %%
df=pd.read_csv("merged_result.csv", encoding = "utf-8")

# %%
df.head()
# Out:
#     지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0  232  천안  2021-01-01 01:00    -9.6      NaN      0.4       0.0   95.0
# 1  232  천안  2021-01-01 02:00   -10.0      NaN      0.3       0.0   94.0
# 2  232  천안  2021-01-01 03:00   -11.0      0.0      0.2       0.0   94.0
# 3  232  천안  2021-01-01 04:00   -11.6      NaN      0.5      90.0   93.0
# 4  232  천안  2021-01-01 05:00   -12.3      NaN      0.0       0.0   91.0
#
#    현지기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)
# 0     1017.6     NaN        NaN     1.0        0.0
# 1     1017.6     NaN        NaN     1.0        0.0
# 2     1018.2     NaN        NaN     1.0        0.0
# 3     1017.9     NaN        NaN     0.9        1.0
# 4     1017.6     NaN        NaN     0.9        4.0

# %%
df = df.drop(columns=["지점"])

# %%
df.head()
# Out:
#   지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  현지기압(hPa)  \
# 0  천안  2021-01-01 01:00    -9.6      NaN      0.4       0.0   95.0     1017.6
# 1  천안  2021-01-01 02:00   -10.0      NaN      0.3       0.0   94.0     1017.6
# 2  천안  2021-01-01 03:00   -11.0      0.0      0.2       0.0   94.0     1018.2
# 3  천안  2021-01-01 04:00   -11.6      NaN      0.5      90.0   93.0     1017.9
# 4  천안  2021-01-01 05:00   -12.3      NaN      0.0       0.0   91.0     1017.6
#
#    일조(hr)  일사(MJ/m2)  적설(cm)  전운량(10분위)
# 0     NaN        NaN     1.0        0.0
# 1     NaN        NaN     1.0        0.0
# 2     NaN        NaN     1.0        0.0
# 3     NaN        NaN     0.9        1.0
# 4     NaN        NaN     0.9        4.0

# %%
df.to_csv("천안 병합.csv", encoding = "utf-8")
